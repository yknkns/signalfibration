# %% [markdown]
# # 00-1. Preprocessing (CPTAC-S045)

# %%
library(data.table)
library(vespa)

# %%
if (!dir.exists("./data/cptac-s045")) {
  out <- system2(
    "bash",
    "./tools/scripts/cptac-s045.sh",
    stdout = TRUE,
    stderr = TRUE
  )

  cat(out, sep = "\n")
}
